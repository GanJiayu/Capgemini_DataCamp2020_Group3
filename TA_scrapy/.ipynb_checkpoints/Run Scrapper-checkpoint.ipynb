# %% [markdown]
# # Scrapping Exercises - Part 2 - 1
#
# Using the selectors from the previous part, we created a spider which get all the information from polytechnique actu page.
# We suggest you to run it through this notebook and to have a look to the produced data.
#
# Your next challenge will be to write your own spider.

# %% [markdown]
# ## 1. Making imports

# %%
# Imports
import os
import json
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Set seaborn display
sns.set()

# %% [markdown]
# ## 2. Running Spider (Brokan 39)

# %%
# Parameters for spider execution
file_path = '../scrapped_data/'
file_name = 'BK39_data3.jl'
spider_name = 'BROKAN'
path = file_path + file_name

# Check if file already exists
# if file_name in os.listdir(file_path):
#    _ = os.remove(path)

# %%
# Execution of spider
cmd1 = 'cd ../TA_scrapy/'
cmd2 = 'scrapy crawl {} -o {} -a max_page=416 -a max_review=200 -a min_review=500'.format(spider_name, path)
cmd = cmd1 + ' && ' + cmd2
_ = os.system(cmd)

if _==0:
    print("Scrapping finished.")
else:
    print('Look at the bash to understand error.')
# Out:
# Scrapping finished.

# %%
# Function rto read jl file
def read_jl_file(file_name):
    values = []
    with open(file_name, 'rb') as f:
        line = '---'
        while len(line)>1:
            line = f.readline()
            values.append(line)
    values = values[:-1]
    values = [json.loads(i) for i in values]
    df = pd.DataFrame(values)
    return df

# Reading file
df_brokan = read_jl_file(path)

# %%
df_brokan
# Out:
#               Restaurant Name  Review ID            Date  \
# 0   BOKAN 38 Bar & 39 Rooftop  724684511    October 2019
# 1   BOKAN 38 Bar & 39 Rooftop  727959956   November 2019
# 2   BOKAN 38 Bar & 39 Rooftop  731680592    October 2019
# 3   BOKAN 38 Bar & 39 Rooftop  731258294   November 2019
# 4   BOKAN 38 Bar & 39 Rooftop  730058592     August 2019
# 5   BOKAN 38 Bar & 39 Rooftop  742334709   February 2020
# 6   BOKAN 38 Bar & 39 Rooftop  731906126   December 2019
# 7   BOKAN 38 Bar & 39 Rooftop  740082393    January 2020
# 8   BOKAN 38 Bar & 39 Rooftop  728349677   November 2019
# 9   BOKAN 38 Bar & 39 Rooftop  735164769   December 2019
# 10  BOKAN 38 Bar & 39 Rooftop  723743170   November 2019
# 11  BOKAN 38 Bar & 39 Rooftop  708611677  September 2019
# 12  BOKAN 38 Bar & 39 Rooftop  700661937     August 2019
# 13  BOKAN 38 Bar & 39 Rooftop  710680106  September 2019
# 14  BOKAN 38 Bar & 39 Rooftop  703074122     August 2019
# 15  BOKAN 38 Bar & 39 Rooftop  713299145  September 2019
# 16  BOKAN 38 Bar & 39 Rooftop  715183063  September 2019
# 17  BOKAN 38 Bar & 39 Rooftop  719884089    October 2019
# 18  BOKAN 38 Bar & 39 Rooftop  721787500       July 2019
# 19  BOKAN 38 Bar & 39 Rooftop  717949140  September 2019
# 20  BOKAN 38 Bar & 39 Rooftop  682492047       June 2019
# 21  BOKAN 38 Bar & 39 Rooftop  699695135     August 2019
# 22  BOKAN 38 Bar & 39 Rooftop  682132611       June 2019
# 23  BOKAN 38 Bar & 39 Rooftop  687782962       July 2019
# 24  BOKAN 38 Bar & 39 Rooftop  685661964       June 2019
# 25  BOKAN 38 Bar & 39 Rooftop  684542863       July 2018
# 26  BOKAN 38 Bar & 39 Rooftop  699606818     August 2019
# 27  BOKAN 38 Bar & 39 Rooftop  694224674       July 2019
# 28  BOKAN 38 Bar & 39 Rooftop  695571146     August 2019
# 29  BOKAN 38 Bar & 39 Rooftop  690181494       July 2019
# 30  BOKAN 38 Bar & 39 Rooftop  679069080       June 2019
# 31  BOKAN 38 Bar & 39 Rooftop  681411884        May 2019
# 32  BOKAN 38 Bar & 39 Rooftop  677601416        May 2019
# 33  BOKAN 38 Bar & 39 Rooftop  678843352       June 2019
#
#                                               Content  Rating
# 0   Stayed in Novotel. Used Boken bar on 38th floo...     3.0
# 1   First waiting for a table at the entrance to s...     2.0
# 2   Me and my girlfriend went for couple of drinks...     5.0
# 3   Went for a drink at the bar but was ignored by...     1.0
# 4   Perfect roof top bar in Canary Wharf for summe...     5.0
# 5   Bokan is a 3 level rooftop bar, with a view ov...     5.0
# 6   This was my first time visiting the Bokan havi...     5.0
# 7   It's obvious most come for the views which are...     4.0
# 8   I was reccomended this venue by a waiter in an...     5.0
# 9   We visited the bar in December 2019. Waiting f...     2.0
# 10  My wife and I celebrated our 1-year anniversar...     1.0
# 11  This wasn’t my first time at Bokan’s but this ...     2.0
# 12  Stunning views from both inside and out. Busy ...     5.0
# 13  Ate here with friends from out of town, had be...     3.0
# 14  I guess the main reason for visiting Bokan if ...     4.0
# 15  Worth the view. We popped in here for a drink ...     4.0
# 16  Went after work last few for couple of drinks ...     3.0
# 17  The views to the city with the tower bridge an...     5.0
# 18  We loved it! Absolutely fabulous view. Service...     5.0
# 19  Visited here in Sept with my son so that we co...     5.0
# 20  I absolutely love this place! I make sure I st...     5.0
# 21  I ve been for the first time there, nice view ...     2.0
# 22  Spotted this place whilst staying at neighbour...     5.0
# 23  Nice decor, friendly staff, great views, good ...     4.0
# 24  I visited the Bar and rooftop for date night l...     4.0
# 25  I arrived in an evening with friends, the view...     5.0
# 26       We are staying at the hotel, had lunch here.     5.0
# 27  Although the menu is somewhat limited, with a ...     4.0
# 28  I went on a walk on Sunday evening and was not...     5.0
# 29  Stayed at the Novotel for the fourth time and ...     3.0
# 30  The place it's situated on the 38th floor of N...     4.0
# 31  Both bars very nice, decor lovely, views amazi...     5.0
# 32  This place has a real buzz about it and some o...     4.0
# 33  The atmosphere here was lovely. The view was t...     5.0

# %%
df_brokan.to_csv(file_path+"Scraped_Brokan.csv")

# %% [markdown]
# ## 2. Running the spider (ALL Resturants with at least 500 reviews on TA in London)
#
# (The process might take over one minute if you remove the __"-a nb_article_max=100"__ to get all the articles)

# %%
# Parameters for spider execution
file_path = '../scrapped_data/'
file_name = 'BK39_data2.jl'
spider_name = 'ZQR'
path = file_path + file_name

# Check if file already exists
#if file_name in os.listdir(file_path):
#    _ = os.remove(path)

# %%
# Execution of spider
cmd1 = 'cd ../TA_scrapy/'
cmd2 = 'scrapy crawl {} -o {} -a max_page=416 -a max_review=200 -a min_review=500'.format(spider_name, path)
cmd = cmd1 + ' && ' + cmd2
_ = os.system(cmd)

if _==0:
    print("Scrapping finished.")
else:
    print('Look at the bash to understand error.')

# %% [markdown]
# ## 3. Reading scrapped data

# %%
# Function rto read jl file
def read_jl_file(file_name):
    values = []
    with open(file_name, 'rb') as f:
        line = '---'
        while len(line)>1:
            line = f.readline()
            values.append(line)
    values = values[:-1]
    values = [json.loads(i) for i in values]
    df = pd.DataFrame(values)
    return df

# Reading file
df = read_jl_file(path)

# %%
# Having a brief look at data
print(df.shape)

df2 = df.iloc[:10000,:]
# Out:
# (488413, 5)

# %%
df2
# Out:
#      Restaurant Name  Review ID            Date  \
# 0            Madhu's  739447935    January 2020
# 1            Madhu's  739773109    January 2020
# 2            Madhu's  738529074    January 2020
# 3            Madhu's  739981237    January 2020
# 4            Madhu's  740251404    January 2020
# ...              ...        ...             ...
# 9995   Bistro Benito  173256622     August 2013
# 9996   Bistro Benito  177905225  September 2013
# 9997   Bistro Benito  180172952  September 2013
# 9998   Bistro Benito  177699004  September 2013
# 9999   Bistro Benito  181944154    October 2013
#
#                                                 Content  Rating
# 0     The food was absolutely wonderful from prepara...     5.0
# 1     The food was amazing. Our waiter Franco was ex...     5.0
# 2     It was an awesome experience dining at the res...     5.0
# 3     Excellent service, excellent food and great am...     5.0
# 4     Food was good cannot say too good but staff an...     4.0
# ...                                                 ...     ...
# 9995  A little cramped, a little dated in decor, but...     4.0
# 9996  Good Italian food, and a great staff. The owne...     4.0
# 9997  Maybe we visited on a bad night but I can't se...     2.0
# 9998  We went after seeing other reviews while on a ...     4.0
# 9999  Visited on an evening in favour of the chain I...     4.0
#
# [10000 rows x 5 columns]

# %%
df2.to_csv(file_path+"Allresto.csv")

# %%
RN = df['Restaurant Name'].unique()

# %%
RN
# Out:
# array(["Madhu's", 'La Dolce Vita', 'Mezzet Lebanese Restaurant',
#        'The French Table', 'Q Verde', 'Jaipur of Chigwell',
#        'Friends Restaurant', 'The Andover Arms',
#        'The Pheasant Restaurant & Pheasant Inn', 'The George',
#        'The Estate Grill at Great Fosters', 'Lokkum Bar and Grill',
#        'Red Peppers Esher', 'The Hare at Old Redding',
#        'Turtle Bay - Walthamstow', 'The Queens Head', 'Gola Restaurant',
#        'Little India', 'The George Harvester', 'Portobello Ristorante',
#        "Maggie Jones's", 'Holy Smoke', 'TortelliniCup',
#        'Brasserie Vacherin', 'Scoff & Banter Kensington',
#        'Fiddie’s Italian Kitchen', 'Coda Restaurant by Eric Chavot',
#        'Steak & Co. Gloucester Road Kensington', 'The Hereford Arms',
#        'Bistro Benito', 'The Victoria', 'Bella Italia Windsor Royal',
#        'Boxpark Croydon', 'The Bailiwick', 'Indian Moment',
#        'Zonzo Restaurant', 'Toby Carvery Langley Slough Restaurant',
#        "Khan's of Kensington", 'The Meat Co', 'The Arkley',
#        'The Monkey Puzzle', 'ASK Italian', "The Queen's Arms",
#        'Urban Meadow Cafe & Bar', 'Frankie & Benny’s', 'Pierino',
#        'Seven Park Place by William Drabble', 'The Summerhouse', 'Rabbit',
#        'Murano', "Sophie's Steakhouse - Chelsea", 'Farm Girl',
#        'Maroush Express', 'The Minnow', 'Celeste', 'The Apple Tree',
#        "Muriel's Kitchen - South Kensington", 'Kayal', 'Le Bab',
#        'Kazan Kitchen', '2 Veneti', 'Tozi Restaurant & Bar',
#        'The Colony Grill Room', 'Burger and Lobster at Harvey Nichols',
#        'The Alfred Tennyson', 'Chisou Japanese Restaurant', 'Kai Mayfair',
#        'Casa Brindisa South Kensington', 'Tota', 'The Albany',
#        'Flat Iron Beak Street', 'The Clink Restaurant', 'Mari Vanna',
#        "Garfunkel's", 'La Sorrentina', 'Frog By Adam Handling',
#        '45 Jermyn St.', 'Steak & Co. Leicester Square Charing Cross',
#        'Guinea Grill', "Franco's", 'Flat Iron Covent Garden',
#        'The Marquis of Westminster', 'Sofra - Mayfair', 'Pierre Victoire',
#        '10 Greek Street', 'Bar 61 Restaurant', 'Tiger Green Brasserie',
#        "Carluccio's South Kensington", "Mr Fogg's Residence",
#        'Phoenix Palace', 'Poppies Fish and Chips Camden',
#        'Mildreds Camden', 'Bibendum Oyster Bar', 'Barrafina',
#        'The Good Earth', 'Big Easy - Chelsea', 'Hawksmoor Air Street',
#        'East Street', 'Bill’s Baker Street', 'Caffe Concerto', 'Taormina',
#        'Gaucho', 'The Prince of Wales', 'The Real Greek - Soho',
#        'The Lamb & Flag', 'Burger & Lobster - Soho', 'Boqueria',
#        'Union Tavern', 'Sketch Glade', "Cecconi's Mayfair",
#        'Iberica Marylebone', 'Novikov Restaurant & Bar',
#        'Gordon Ramsay Bar & Grill', 'Delhi Brasserie - Soho',
#        'Whyte and Brown', 'Mnky Hse', 'The Star Pub', 'Al Duca',
#        "Rowley's", 'Franco Manca', 'The Black Dog Freehouse',
#        'Brasserie Zedel', "Gillray's Steakhouse & Bar",
#        'Tas Restaurant Bloomsbury', 'Bravi Ragazzi Pizza',
#        'Loco Mexicano', 'Smith & Wollensky UK',
#        'The Ivy Cobham Brasserie', 'Jinjuu Soho',
#        'Everest Spice Nepalese and Indian Restaurant', 'Byron', 'Cosmoba',
#        'Colosseo Restaurant',
#        'Mon Plaisir Restaurant, Covent Garden, French', 'Andrew Edmunds',
#        "Stovell's", 'The Savoy Grill', 'German Gymnasium', 'Porcupine',
#        'Blue Boar Restaurant', 'Tao Tao Ju', 'Sen Viet',
#        'Forty Dean Street', 'Cafe Monico', 'VQ Bloomsbury',
#        'Angus Steakhouse', 'Cafe Pacifico',
#        'San Carlo Cicchetti- Covent Garden', 'Buddha-Bar London',
#        'Oxo Tower Restaurant, Bar and Brasserie', 'Pasta Brown',
#        'Serpentine Bar & Kitchen', 'Browns Victoria',
#        'The Riding House Cafe', 'Tower Tandoori Restaurant',
#        'Masala Zone Covent Garden', "Wild Food Cafe, Neal's Yard",
#        'Red Lion', "O'Neill's - Kings Cross", 'Uno',
#        'The Old Bank of England', 'The Royal Saracens Head',
#        'Spaghetti House - Haymarket', 'Angler', 'Dans Le Noir ? London',
#        'Cinnamon Soho', 'Busaba Covent Garden', 'Hawksmoor Borough',
#        'Olivelli - Waterloo', 'La Petite Auberge',
#        'Flat Iron Curtain Road', 'The Blackfriar', 'Pizzeria Pappagone',
#        'Crusting Pipe', 'Planet Hollywood', 'wagamama',
#        'Hubbard and Bell', 'Bengal Village',
#        'Gilgamesh Restaurant Lounge Bar', 'Padella',
#        'Ye Olde Cheshire Cheese', 'Thai Square Trafalgar Square',
#        'The Nightjar', 'Omnino Leadenhall', 'Iberica Farringdon', 'Zizzi',
#        'Belgo Holborn', 'Union Street Cafe', 'Melanie Restaurant',
#        'Royal China - Baker Street', 'E Pellicci', "Smith's",
#        'Tierra Peru', 'Joy King Lau', 'Tattershall Castle',
#        'Fratelli La Bufala', "L'Ulivo", "Bill's Islington",
#        'Casse-Croute', 'St John Bar & Restaurant Smithfield',
#        'Bella Italia', 'Gourmet Pizza Company', 'Fenchurch', 'Swan',
#        'Shakespeares Head', 'Jose Tapas Bar', "Applebee's Fish",
#        'Burger & Lobster - City', 'Tas Restaurant The Cut',
#        "Carluccio's - Covent Garden", 'The Anchor and Hope',
#        "Gilbey's - Old Amersham", 'Trullo', 'Boro Bistro',
#        'La Bodega Negra Restaurant', 'The Table Cafe',
#        'Tuttons Brasserie', 'Hawksmoor Guildhall',
#        'Trattoria Verdi Restaurant', 'Sea Containers Restaurant',
#        'Bubba Gump Shrimp Co', "St. Stephen's Tavern", 'Roadhouse',
#        'The Banc', 'Vanilla Black', 'Cafe Murano - Covent Garden',
#        'Sagar Restaurant (Vegetarian) Ltd', 'Tiger Tiger',
#        'The Restaurant at Sanderson', 'The Piano Works Farringdon',
#        'Arabica Bar & Kitchen', 'Cay Tre Soho',
#        'Sfoglia Bologna al Mattarello', 'Black and Blue', 'Hix',
#        'The Albert Pub Victoria Street', 'Stax Diner',
#        'Dishoom Shoreditch', 'Ottolenghi - Islington',
#        'Beefeater Monkey Puzzle - Chessington',
#        'Northbank Restaurant & Bar', 'York & Albany Restaurant',
#        'The Crazy Bear - Fitzrovia', 'Chez Elles Bistroquet', '12th Knot',
#        'Paternoster Chop House', 'Spaghetti House', 'Restaurant Story',
#        'The Diner - Camden', 'Jeitta Lebanese Cuisine', 'The Monsoon',
#        'La Porchetta Pollo Bar', 'Number Twelve', 'St Pancras by Searcys',
#        'The Ivy Soho Brasserie', 'The Shy Horse', 'The Sun Inn',
#        "Bill's Holborn", 'The Cricketers', 'La Ballerina', 'Rabot 1745',
#        'The Wallace', 'Three Stags', 'The Brickmakers', 'Lobos',
#        'Cote Brasserie - St Pauls', 'Dirty Bones Shoreditch',
#        'The Marlborough Head', 'Salieri Restaurant', 'The Parcel Yard',
#        'Bel and the Dragon', 'The Fire Station', 'Eat Tokyo',
#        'The Marquis Cornwallis', 'Assaggetti', 'Galvin La Chapelle',
#        'The Bear & Staff', 'Santore', 'Hi Sushi Salsa', 'Wildwood',
#        'Yuu Kitchen', "Henry's Cafe Bar - Piccadilly",
#        'Strada Royal Festival Hall', "Caravan King's Cross", 'MEATliquor',
#        'Skylon Restaurant', 'Franco Manca Brixton', "The World's End",
#        'The Crown At Bray', 'OXBO Bankside', 'Vapiano - Soho',
#        'Barshu Restaurant', 'Kettners', 'Salsa! Temple',
#        'The Clarence, Whitehall', 'Floral by Lima',
#        'The Artichoke Restaurant', 'Wright Brothers', 'temper Soho',
#        'Bianco43 - Trafalgar Square', 'The Gilbert Scott',
#        'Preto Victoria', 'Piccolino', 'Wahaca Waterloo',
#        'Hispania London', 'The Chiltern Firehouse',
#        'The Stables @ The Grove', 'Goodman City',
#        'Las Iguanas - Royal Festival Hall', 'Circus', 'The Rose',
#        'Loch Fyne - Cobham', 'Granary Square Brasserie', 'Granger & Co',
#        'Granaio', 'Bill’s Epsom', 'The Black Swan', 'Plum and Spilt Milk',
#        'Polpo Soho', "Jimmy's Restaurant", 'Rock & Sole Plaice',
#        'The Crazy Bear Beaconsfield - Thai Restaurant',
#        'Nags Head, Covent Garden', 'Zafari Bar & Grill',
#        'Holborn Dining Room', 'Bill’s Covent Garden', 'The Archduke',
#        'The Booking Office', 'The Megaro', 'Pure Cyprus',
#        'The Glasshouse @ The Grove', 'Belgo Centraal', 'Rasa Sayang',
#        'Indian City', 'Fumo', 'POLPO Covent Garden', 'Beijing Dumpling',
#        'Troia Southbank Charcoal Kebab Kitchen', 'Bubbledogs',
#        'Bella Italia - London St Martins Lane', "Rosa's Thai Cafe Soho",
#        'The Clock House', 'Prezzo - Victoria Place', 'The Parlour',
#        'Fredericks Restaurant', 'Wagamama Covent Garden', 'Bibimbap',
#        'Terroirs', 'Jackson + Rye', 'Drink, Shop & Do', "Carluccio's",
#        'The White Oak', 'Wahaca Southbank', 'The Rum Kitchen',
#        'Rossopomodoro - Camden', 'Poppies Fish & Chips Soho',
#        'Cafe in the Crypt', "Maxwell's Bar and Grill",
#        'Rucoletta Neapolitan Eatery', 'Club Gascon', 'Wan Chai Corner',
#        'Vapiano - Great Portland Street', 'Busaba Leicester Square',
#        'Mildreds Kings Cross', 'TGI Fridays',
#        'Suda Thai Cafe & Restaurant', 'Rossopomodoro - Covent Garden',
#        'The Belvedere Arms', 'Cinnamon Bazaar', 'New Loon Fung',
#        'The Wellington', 'Flesh and Buns Covent Garden', 'The Dairy',
#        'The Feathers', 'Turtle Bay - Brixton', 'M Victoria Street',
#        'Chiquito', "Bill's Covent Garden (St Martin's Courtyard)",
#        'Princi', "Bag O' Nails", 'Prezzo - Euston',
#        'Bone Daddies Ramen Bar', 'Baltic Restaurant & Bar',
#        'Comedor Grill & Bar', 'The Four Horseshoes', 'Sketch Parlour',
#        'Mr India', 'Bleeding Heart Restaurant',
#        'Brasserie Blanc Southbank', 'Latino', 'Busaba Bloomsbury',
#        'St James Tavern', 'Taste of India', 'Sketch Gallery',
#        'The Spaniards Inn', 'Great Queen Street', "Christopher's",
#        'Fish Central', 'Orient', "Giovanni's", 'ROKA Aldwych',
#        'Mele e Pere', 'Ciao Bella', 'Masters Superfish',
#        'Mint Leaf Restaurant & Bar', 'Getti Jermyn Street', 'The Elysee',
#        "Prezzo Italian Restaurant London King's Cross", 'Sticky Mango',
#        'Miller & Carter Steakhouse', 'Gaucho - Chancery Lane',
#        'The Pig and Butcher', 'Pera Restaurant islington',
#        'The Porterhouse Covent Garden', 'Balthazar', 'Sarastro',
#        'Laughing Gravy Bar & Restaurant', "Fuller's Pie and Ale House",
#        'Yalla Yalla', 'The Jack Horner', 'Bali Bali',
#        'Benihana Piccadilly', 'Tredwells', 'Sartori Restaurant',
#        'Joe Allen', 'Spring', 'Le Garrick Brasserie Restaurant',
#        'One Twenty One Two Restaurant', 'The Ivy Market Grill',
#        'La Barca Ristorante', 'R.S.Hispaniola', 'The White Lion',
#        'Boulters Riverside Brasserie & Terrace Bar', 'Lima',
#        'The Diner - Soho', 'Boyds Grill & Wine Bar', 'Il Baretto',
#        'Bella Italia Strand', "Camino King's Cross",
#        'LE RESTAURANT DE PAUL, COVENT GARDEN', 'Hoppers Soho',
#        'Salsa! Soho', 'Aqua Kyoto', 'Chotto Matte London', 'Pho',
#        'Roti King', 'Quo Vadis', 'The Terrace on Piccadilly',
#        'Museum Tavern', 'Browns Brasserie & Bar Mayfair', 'Com Viet',
#        'Brasserie Joel', 'Malabar Junction', "The Hind's Head, Bray",
#        'The Diamond Jubilee Tea Salon', 'Masala Zone Soho',
#        'Opera Tavern', 'Social Eating House', 'Ethos', 'Isolabella',
#        'Khan’s', 'Mango Tree', 'Riverside Brasserie', 'Cote Brasserie',
#        'The Coy Carp', 'Sexy Fish', 'The Duck & Rice',
#        'Honest Burgers - Covent Garden', 'Park Chinois',
#        "Cote Brasserie - St Martin's Lane", 'Niche Gluten-free Dining',
#        'Ceviche Soho', 'Balans Soho Society', 'Yauatcha Soho',
#        'The Red Lion', 'Al Forno - Wimbledon', 'Busaba Soho',
#        'The Real Greek - Covent Garden', 'Cabana Covent Garden',
#        'The Blues Kitchen - Brixton', 'Tandoor Chophouse',
#        'Tapas Brindisa Soho', 'Mestizo', 'Cinnamon Club',
#        'Bunga Bunga Covent Garden', 'Spuntino', "Kerridge's Bar & Grill",
#        'Berners Tavern', 'San Marco Ristorante & Pizzeria',
#        'The Ship Tavern', 'Dean Street Townhouse Hotel & Dining Room',
#        'Patara Fine Thai Restaurant - Oxford Circus',
#        'Giraffe - Victoria', 'Sake no Hana', 'The Delaunay', 'Pix',
#        "Honest Burgers - King's Cross", 'The Cambridge',
#        'Wildwood Kitchen', 'Jamon Jamon - Soho', "Bodean's BBQ - Soho",
#        'Misato', 'Punjab', 'London Hong Kong', 'The Argyll Arms',
#        'Battle Axes Restaurant', 'Zeret Kitchen', 'Souk Medina',
#        'Bocconcino Restaurant', 'Ping Pong Soho', 'Thames Court',
#        'The Swan', 'Dehesa', 'Aster', 'Tokyo Diner', 'The Boot',
#        'Wahaca Charlotte St', 'Wolkite restaurant', "Hudson's House",
#        'The Clachan', 'Hakkasan Hanway Place Restaurant', 'Aqua Nueva',
#        "Homeslice Neal's Yard", 'Bistro 1 - Frith Street',
#        'Boisdale of Belgravia', 'Thames Foyer at The Savoy',
#        'Restaurant Ours', 'Cafe Rouge - London Kingsway', 'Wahaca Soho',
#        'Portrait Restaurant', 'Gaucho - Piccadilly',
#        'Bar + Block Steakhouse', 'Wahaca Covent Garden', 'The Phene',
#        'The 10 Cases', 'LEGGERO', 'ROSSODISERA - il marchigiano',
#        'Hand & Spear', 'Indian Sizzler', 'Zizzi - Central St. Giles',
#        'The Yacht London', 'Yming', 'Eneko Basque Kitchen & Bar',
#        'Vietfood', 'Benihana Chelsea', 'Nobu London', 'The Plough Inn',
#        'Ham Yard Restaurant and Bar', 'Indian Lounge',
#        'The Cliveden Dining Room', 'Estiatorio Milos', 'Hakkasan Mayfair',
#        'Wasabi 58 Oxford Street', 'Danson Stables',
#        'China Tang at The Dorchester', 'Pho & Bun', 'The Admiralty',
#        'The Wilmington', 'Locale', 'Hot Stone', 'Ember Yard',
#        'The George on the Strand', 'Mews of Mayfair', 'BAO Soho',
#        'Shoryu Regent Street', 'Nobu Berkeley St', 'Skinners Arms',
#        'Mac & Wild Fitzrovia', 'Kanada-Ya Ramen Bar',
#        "The Ivy St John's Wood", 'The Botanist', 'Antalya Restaurant',
#        'The Northall', 'Piazza', 'Boulevard Brasserie', 'Ichibuns',
#        'Frenchie Covent Garden', 'Momo', 'The Breakfast Club',
#        'Chino Latino', "Mr Fogg's Gin Parlour", "Gordon's Wine Bar",
#        'Prezzo - Northumberland Avenue',
#        'Salvador and Amanda - Covent Garden',
#        'The Crazy Bear Beaconsfield - English Restaurant', 'The Ivy'],
#       dtype=object)

# %%
RNN = []
for rst in RN:
    RNN.append(np.sum(df['Restaurant Name'] == rst))

# %%
len(RNN)
# Out:
# 586

# %%
RNN
# Out:
# [365,
#  4,
#  1177,
#  1145,
#  610,
#  389,
#  9,
#  848,
#  243,
#  9,
#  3,
#  2,
#  3,
#  13,
#  140,
#  736,
#  424,
#  12,
#  449,
#  298,
#  828,
#  474,
#  461,
#  606,
#  422,
#  311,
#  525,
#  1738,
#  947,
#  460,
#  6,
#  23,
#  528,
#  3,
#  42,
#  1,
#  750,
#  1093,
#  778,
#  22,
#  47,
#  681,
#  22,
#  500,
#  645,
#  881,
#  67,
#  16,
#  64,
#  107,
#  1,
#  20,
#  46,
#  743,
#  48,
#  511,
#  1155,
#  59,
#  360,
#  279,
#  13,
#  1116,
#  12,
#  31,
#  36,
#  5,
#  626,
#  1,
#  544,
#  725,
#  760,
#  10,
#  99,
#  1804,
#  470,
#  450,
#  583,
#  1984,
#  546,
#  8,
#  1988,
#  584,
#  685,
#  896,
#  513,
#  1963,
#  538,
#  666,
#  803,
#  1,
#  901,
#  559,
#  828,
#  640,
#  1,
#  9,
#  4,
#  720,
#  8,
#  448,
#  1,
#  8,
#  733,
#  594,
#  753,
#  1950,
#  545,
#  794,
#  447,
#  1125,
#  883,
#  2000,
#  1984,
#  529,
#  737,
#  551,
#  809,
#  477,
#  843,
#  631,
#  584,
#  2000,
#  1371,
#  822,
#  420,
#  437,
#  1067,
#  861,
#  799,
#  746,
#  2479,
#  503,
#  487,
#  979,
#  692,
#  977,
#  2000,
#  2000,
#  513,
#  605,
#  495,
#  555,
#  474,
#  592,
#  583,
#  2810,
#  1030,
#  1653,
#  894,
#  2000,
#  766,
#  606,
#  1221,
#  1288,
#  1138,
#  2000,
#  612,
#  936,
#  718,
#  397,
#  447,
#  821,
#  507,
#  1032,
#  2000,
#  828,
#  848,
#  524,
#  594,
#  558,
#  465,
#  902,
#  735,
#  891,
#  2000,
#  1154,
#  480,
#  687,
#  2000,
#  1052,
#  1441,
#  891,
#  529,
#  406,
#  454,
#  2058,
#  593,
#  1222,
#  602,
#  756,
#  742,
#  1656,
#  560,
#  950,
#  701,
#  813,
#  667,
#  498,
#  529,
#  988,
#  3100,
#  657,
#  1073,
#  1971,
#  352,
#  715,
#  622,
#  974,
#  837,
#  1698,
#  632,
#  617,
#  548,
#  517,
#  1145,
#  645,
#  1667,
#  1048,
#  451,
#  1762,
#  2000,
#  542,
#  678,
#  1177,
#  883,
#  875,
#  804,
#  543,
#  2000,
#  913,
#  781,
#  580,
#  722,
#  467,
#  1162,
#  825,
#  655,
#  2000,
#  1228,
#  996,
#  674,
#  922,
#  1321,
#  446,
#  680,
#  2000,
#  999,
#  763,
#  422,
#  752,
#  1764,
#  455,
#  481,
#  1723,
#  955,
#  555,
#  773,
#  458,
#  1509,
#  700,
#  1178,
#  525,
#  500,
#  1184,
#  672,
#  653,
#  566,
#  399,
#  841,
#  1065,
#  814,
#  749,
#  645,
#  507,
#  489,
#  2000,
#  468,
#  470,
#  424,
#  546,
#  850,
#  586,
#  999,
#  1381,
#  1614,
#  2000,
#  671,
#  395,
#  1056,
#  738,
#  592,
#  447,
#  1262,
#  717,
#  522,
#  668,
#  984,
#  1003,
#  829,
#  391,
#  2000,
#  464,
#  1039,
#  841,
#  411,
#  2000,
#  567,
#  653,
#  1699,
#  986,
#  446,
#  806,
#  590,
#  532,
#  241,
#  538,
#  1163,
#  1196,
#  1458,
#  505,
#  907,
#  637,
#  587,
#  652,
#  1016,
#  628,
#  856,
#  1171,
#  557,
#  489,
#  946,
#  2000,
#  748,
#  601,
#  1001,
#  632,
#  689,
#  1231,
#  728,
#  445,
#  511,
#  718,
#  451,
#  552,
#  630,
#  1015,
#  440,
#  647,
#  953,
#  544,
#  1438,
#  818,
#  1368,
#  922,
#  342,
#  335,
#  1840,
#  2000,
#  595,
#  528,
#  663,
#  850,
#  612,
#  510,
#  648,
#  701,
#  1064,
#  901,
#  758,
#  454,
#  895,
#  1107,
#  571,
#  499,
#  632,
#  631,
#  2000,
#  1410,
#  1671,
#  712,
#  1028,
#  834,
#  1041,
#  988,
#  659,
#  628,
#  657,
#  718,
#  1202,
#  549,
#  499,
#  285,
#  498,
#  2000,
#  563,
#  474,
#  1217,
#  478,
#  610,
#  600,
#  835,
#  877,
#  1156,
#  567,
#  957,
#  474,
#  522,
#  701,
#  581,
#  597,
#  477,
#  527,
#  516,
#  628,
#  2000,
#  1919,
#  1701,
#  491,
#  634,
#  388,
#  497,
#  1071,
#  1868,
#  1138,
#  2000,
#  621,
#  1280,
#  781,
#  2000,
#  541,
#  819,
#  432,
#  1194,
#  1025,
#  675,
#  553,
#  455,
#  940,
#  987,
#  494,
#  760,
#  967,
#  739,
#  1558,
#  436,
#  620,
#  598,
#  486,
#  503,
#  662,
#  632,
#  605,
#  429,
#  2000,
#  1502,
#  915,
#  1111,
#  1318,
#  625,
#  749,
#  543,
#  1449,
#  1244,
#  2000,
#  972,
#  2000,
#  954,
#  396,
#  814,
#  1485,
#  749,
#  1378,
#  1315,
#  2000,
#  959,
#  661,
#  1741,
#  1298,
#  1250,
#  831,
#  489,
#  513,
#  798,
#  2000,
#  741,
#  451,
#  588,
#  2000,
#  500,
#  732,
#  1096,
#  580,
#  778,
#  881,
#  2000,
#  530,
#  685,
#  462,
#  481,
#  1191,
#  1990,
#  597,
#  2000,
#  541,
#  458,
#  791,
#  556,
#  1085,
#  450,
#  1247,
#  1067,
#  369,
#  572,
#  620,
#  583,
#  734,
#  515,
#  425,
#  588,
#  430,
#  2000,
#  522,
#  1248,
#  540,
#  772,
#  1353,
#  586,
#  759,
#  1815,
#  1309,
#  2000,
#  772,
#  2000,
#  645,
#  613,
#  605,
#  315,
#  517,
#  1197,
#  796,
#  1204,
#  642,
#  490,
#  715,
#  516,
#  1903,
#  500,
#  1040,
#  2000,
#  550,
#  540,
#  2000,
#  258,
#  734,
#  937,
#  512,
#  1047,
#  688,
#  2000,
#  537,
#  647,
#  504,
#  846,
#  732,
#  901,
#  1443,
#  426,
#  498,
#  553,
#  504,
#  1003,
#  1054,
#  683,
#  597,
#  2000,
#  780,
#  561,
#  1221,
#  1300,
#  1149,
#  661,
#  1755,
#  929,
#  824,
#  1373,
#  1459]

# %%
nr = 0
for r in RNN:
    if r > 500: nr+=1

# %%
nr
# Out:
# 451

# %%
plt.bar(np.arange(len(RNN)), RNN, )
# Out:
# <BarContainer object of 586 artists>
